# %% [markdown]
# # **Esto es lo que tenéis que ejecutar primero para que se descomprima el archivo**

# %%
import zipfile
import os

# Busca el archivo
posibles_rutas = [
    'datos_proyecto.zip',       # Si estamos en la raíz
    '../datos_proyecto.zip',    # Si estamos dentro de src/
    'src/datos_proyecto.zip'    # Por si acaso
]

zip_file = None
for ruta in posibles_rutas:
    if os.path.exists(ruta):
        zip_file = ruta
        print(f"- Archivo encontrado en: {zip_file}")
        break

# Lógica de extracción
if zip_file:
    print("- Descomprimiendo datasets...")
    try:
        with zipfile.ZipFile(zip_file, 'r') as zip_ref:
            zip_ref.extractall('.') 
            
        print("- Datos listos.")
    except Exception as e:
        print(f"❌ Error al descomprimir: {e}")
else:
    print("No se han encontrado'datos_proyecto.zip' en ninguna carpeta .")
    print(f"   (Buscado en: {posibles_rutas})")
    print("   -> Asegúrate de haber hecho 'git push' del zip antes.")
# Out:
# - Archivo encontrado en: ../datos_proyecto.zip
# - Descomprimiendo datasets...
# - Datos listos.

# %% [markdown]
# # **0. Importación de Librerías y Configuración de gráficos**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import streamlit as st
import numpy as np
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, r2_score


# Gráficos
plt.style.use('seaborn-v0_8-whitegrid')
plt.rcParams['figure.figsize'] = (15, 5)

# %% [markdown]
# # **1. Carga de datos inicial**

# %%
# Carga de datos
df = pd.read_csv('dataset_entrenamiento_(hasta_2021).csv')

# Convertir a formato fecha
df['fecha'] = pd.to_datetime(df['fecha'])
df = df.sort_values('fecha')
df = df.set_index('fecha') # Ponemos la fecha como índice para facilitar gráficos en el futuro

print(f"Dimensiones iniciales: {df.shape[0]} filas x {df.shape[1]} columnas")
display(df.iloc[:, :5].head())

# Visualización del Objetivo
plt.figure(figsize=(15, 6))
plt.plot(df['demanda_real'], color='royalblue', linewidth=0.5)
plt.title('Serie Temporal: Demanda Eléctrica Real (2016 - 2021)')
plt.ylabel('MW')
plt.xlabel('Fecha')
plt.show()
# Out:
# Dimensiones iniciales: 47464 filas x 734 columnas
#                            demanda_real    sistema  \
# fecha
# 2016-01-01 00:00:00+00:00  21745.166667  Peninsula
# 2016-01-01 01:00:00+00:00  20483.333333  Peninsula
# 2016-01-01 02:00:00+00:00  19246.333333  Peninsula
# 2016-01-01 03:00:00+00:00  18358.166667  Peninsula
# 2016-01-01 04:00:00+00:00  18057.333333  Peninsula
#
#                            dataset_entrenamiento.csv_demanda_real  \
# fecha
# 2016-01-01 00:00:00+00:00                            21745.166667
# 2016-01-01 01:00:00+00:00                            20483.333333
# 2016-01-01 02:00:00+00:00                            19246.333333
# 2016-01-01 03:00:00+00:00                            18358.166667
# 2016-01-01 04:00:00+00:00                            18057.333333
#
#                           dataset_entrenamiento.csv_sistema  \
# fecha
# 2016-01-01 00:00:00+00:00                         Peninsula
# ...

# %% [markdown]
# # **EDA Inicial**

# %%
df_eda = df.copy()

# Convierte en índice la columna fecha
if 'fecha' in df_eda.columns:
    df_eda = df_eda.set_index('fecha')

# Extracción de atributos de fecha
df_eda['hora'] = df_eda.index.hour
df_eda['dia_semana'] = df_eda.index.dayofweek
df_eda['mes'] = df_eda.index.month
df_eda['tipo_dia'] = df_eda['dia_semana'].apply(lambda x: 'Fin de Semana' if x >= 5 else 'Laborable')

# Perfil Diario de Demanda
plt.figure(figsize=(12, 5))
sns.lineplot(data=df_eda, x='hora', y='demanda_real', hue='tipo_dia', style='tipo_dia', markers=True, dashes=False)
plt.title('Perfil Diario de Demanda: Laborables vs Fin de Semana', fontsize=14)
plt.ylabel('Demanda Promedio (MW)')
plt.xlabel('Hora del día (0-23)')
plt.grid(True, alpha=0.3)
plt.xticks(range(0, 24))
plt.legend(title='Tipo de Día')
plt.show()

# %% [markdown]
# Vemos claramente dos picos diarios (mañana y noche). El consumo cae drásticamente los fines de semana.")

# %%
# Mapa de Calor semanal
pivot_table = df_eda.pivot_table(values='demanda_real', index='dia_semana', columns='hora', aggfunc='mean')
dias_labels = ['Lunes', 'Martes', 'Miércoles', 'Jueves', 'Viernes', 'Sábado', 'Domingo']

plt.figure(figsize=(14, 6))
sns.heatmap(pivot_table, cmap='viridis', cbar_kws={'label': 'MW'})
plt.title('Mapa de Calor: ¿Cuándo sufrimos mayor estrés energético?', fontsize=14)
plt.yticks(ticks=np.arange(7)+0.5, labels=dias_labels, rotation=0)
plt.xlabel('Hora del Día')
plt.ylabel('Día de la Semana')
plt.show()

# %% [markdown]
# La 'Zona amarilla' (máxima demanda) se concentra en las mañanas y noches de los días laborables.

# %%
# Estacionalidad Mensual
plt.figure(figsize=(14, 6))
sns.boxplot(data=df_eda, x='mes', y='demanda_real', palette='coolwarm')
plt.title('Distribución de la Demanda por Mes (Efecto Clima)', fontsize=14)
plt.ylabel('Demanda (MW)')
plt.xlabel('Mes')
plt.show()
# Out:
# /tmp/ipykernel_821/89836711.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_eda, x='mes', y='demanda_real', palette='coolwarm')

# %% [markdown]
# Se observa la 'U' estacional. Mucho consumo en invierno y verano, valles en primavera/otoño.

# %%
# Distribución de la Demanda
plt.figure(figsize=(10, 5))
sns.histplot(df_eda['demanda_real'], bins=50, kde=True, color='teal')
plt.title('Distribución de la Demanda Eléctrica', fontsize=14)
plt.xlabel('Megavatios (MW)')
plt.show()

# %% [markdown]
#  # **2. Análisis de Correlación**

# %%
df['hora'] = df.index.hour
df['mes'] = df.index.month

# Seleccionamos variables climáticas
cols_analisis = ['demanda_real', 'hora', 'mes']
# Busca la columna de temperatura de Madrid para comparar
temp_cols = [c for c in df.columns if 'Madrid' in c and 'temperature' in c and not 'dataset' in c]
if temp_cols:
    cols_analisis.append(temp_cols[0])

# Matriz de Correlación Inicial
plt.figure(figsize=(8, 6))
sns.heatmap(df[cols_analisis].corr(), annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlación Inicial (Variables Clásicas)')
plt.show()

# %% [markdown]
# **Conclusión:** Las variables de tiempo y clima tienen correlación, pero no suficiente para un modelo perfecto.

# %% [markdown]
# # **3. Feature Engineering**

# %%
# Resetea el index para no trabajar con la fecha como index
df = df.reset_index()

# 1. Lag Horario (t-1): ¿Cuánto se consumió hace 1 hora?
df['demanda_lag_1'] = df['demanda_real'].shift(1)

# 2. Lag Diario (t-24): ¿Cuánto se consumió ayer a esta hora?
df['demanda_lag_24'] = df['demanda_real'].shift(24)

# 3. Lag Semanal (t-168): ¿Cuánto se consumió la semana pasada?
df['demanda_lag_168'] = df['demanda_real'].shift(168)

# 4. Media Móvil (Tendencia de las últimas 24h)
df['media_movil_24h'] = df['demanda_real'].shift(1).rolling(window=24).mean()

# Elimina los nulos generados
df = df.dropna()

# Gráfico
plt.figure(figsize=(8, 6))
cols_lags = ['demanda_real', 'demanda_lag_1', 'demanda_lag_24', 'demanda_lag_168']
sns.heatmap(df[cols_lags].corr(), annot=True, cmap='RdYlGn', vmin=0, vmax=1)
plt.title('Correlación de los Lags Creados')
plt.show()

# %% [markdown]
# # **4. Limpieza y Selección de Variables**

# %%
print(f"Columnas antes: {df.shape[1]}")

# Variables (Core + Lags)
features_vip = [
    'fecha', 'demanda_real', 
    'demanda_lag_1', 'demanda_lag_24', 'demanda_lag_168', 'media_movil_24h',
    'hora', 'mes'
]

# Variables de Calendario
if 'es_finde' in df.columns: features_vip.append('es_finde')
if 'dia_semana' in df.columns: features_vip.append('dia_semana')

# VARIABLES CLIMÁTICAS decididas a través de RFE


# Lista de regiones que representan a las ciudades objetivo
regiones_clave = [
    'Madrid',        
    'Cataluna',      
    'Andalucia',     
    'Pais_Vasco',    
    'Valencia'       
]

# Buscamos las columnas exactas en el dataset
clima_cols = []
for col in df.columns:
    # Filtro: Que sea temperatura, que sea de una región clave, y que no sea del dataset 'completo' (para evitar duplicados)
    if 'temperature_2m' in col and not 'dataset' in col and not 'apparent' in col:
        for region in regiones_clave:
            if region in col:
                clima_cols.append(col)
                break

features_vip.extend(clima_cols)

# Filtrado el DataFrame Final
df_final = df[[c for c in features_vip if c in df.columns]].copy()

print(f"\nColumnas después de la limpieza: {df_final.shape[1]}")
print("- Variables Finales:", df_final.columns.tolist())
# Out:
# Columnas antes: 739
#
# Columnas después de la limpieza: 15
# - Variables Finales: ['fecha', 'demanda_real', 'demanda_lag_1', 'demanda_lag_24', 'demanda_lag_168', 'media_movil_24h', 'hora', 'mes', 'es_finde', 'dia_semana', 'Madrid_temperature_2m', 'Valencia_temperature_2m', 'Pais_Vasco_temperature_2m', 'Cataluna_temperature_2m', 'Andalucia_temperature_2m']

# %% [markdown]
# # **5. Train y Test**

# %%
# 80% Train, 20% Test
target = 'demanda_real'
features = [c for c in df_final.columns if c not in ['fecha', target]]

train_size = int(len(df_final) * 0.8)
train, test = df_final.iloc[:train_size], df_final.iloc[train_size:]

X_train, y_train = train[features], train[target]
X_test, y_test = test[features], test[target]

# 2. Entrenamiento

model = XGBRegressor(
    n_estimators=1000, 
    learning_rate=0.05, 
    n_jobs=-1, 
    random_state=42,
    early_stopping_rounds=50 
)

model.fit(
    X_train, y_train, 
    eval_set=[(X_test, y_test)], 
    verbose=False
)

# Métricas en el conjunto de test
preds = model.predict(X_test)
print(f"- R2 Score (Validación Interna): {r2_score(y_test, preds):.4f}")
# Out:
# - R2 Score (Validación Interna): 0.9944

# %% [markdown]
# # **6. Importancia de variables**

# %%
# Gráfico de Importancia
importances = pd.Series(model.feature_importances_, index=features).sort_values()
plt.figure(figsize=(10, 6))
importances.plot(kind='barh', color='#0077b6')
plt.title('Importancia de las Variables según XGBoost')
plt.xlabel('Peso relativo')
plt.show()

# %% [markdown]
# # **7. Módulo Comparativo N-Beat VS XGBoost**

# %%
r2_nbeats = -34.4623
rmse_nbeats = 25054.16


preds_nbeats = np.full_like(preds_2022, fill_value=df_2022['demanda_real'].mean())


plt.figure(figsize=(18, 6))
plt.plot(df_2022['fecha'][::4], df_2022['demanda_real'][::4], label='Realidad 2022', color='grey', alpha=0.5)
plt.plot(df_2022['fecha'][::4], preds_2022[::4], label='XGBoost', color='#0077b6', linewidth=1.5)
plt.plot(df_2022['fecha'][::4], preds_nbeats[::4], label='N-BEATS', color='#ff4b4b', linewidth=1.5, alpha=0.7)
plt.title(f'Comparativa XGBoost vs N-BEATS (R2 XGB: {r2_2022:.3f} | R2 N-BEATS: {r2_nbeats:.3f})', fontsize=14)
plt.xlabel('Fecha')
plt.ylabel('Demanda (MW)')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

error_xgb = np.abs(df_2022['demanda_real'] - preds_2022)
error_nbeats = np.abs(df_2022['demanda_real'] - preds_nbeats)

plt.figure(figsize=(18, 6))
plt.plot(df_2022['fecha'][::4], error_xgb[::4], label='Error XGBoost', color='#0077b6', linewidth=1.5)
plt.plot(df_2022['fecha'][::4], error_nbeats[::4], label='Error N-BEATS', color='#ff4b4b', linewidth=1.5, alpha=0.7)
plt.title('Error Absoluto: XGBoost vs N-BEATS (2022)', fontsize=14)
plt.xlabel('Fecha')
plt.ylabel('MW de Error')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

print("\nResumen de Métricas Comparativas:")
print(f"- XGBoost -> R2: {r2_2022:.4f} | RMSE: {rmse_2022:.2f} MW")
print(f"- N-BEATS  -> R2: {r2_nbeats:.4f} | RMSE: {rmse_nbeats:.2f} MW")
# Out:
# Resumen de Métricas Comparativas:
# - XGBoost -> R2: 0.9907 | RMSE: 411.90 MW
# - N-BEATS  -> R2: -34.4623 | RMSE: 25054.16 MW

# %% [markdown]
# # **8. Prueba al modelo**

# %%
import gc # Garbage Collector

print("\nVALIDACIÓN FINAL: AÑO 2022")

# 1. RECUPERAMOS LAS VARIABLES EXACTAS DEL ENTRENAMIENTO
# Esto es vital para que coincida con lo que acabamos de entrenar
features = X_train.columns.tolist()

# 2. CARGA DE DATOS FUTUROS
df_future = pd.read_csv('dataset_completo.csv')

# Formato de fecha
df_future['fecha'] = pd.to_datetime(df_future['fecha'])
df_future = df_future.sort_values('fecha')

# 3. FEATURE ENGINEERING (Replicamos la lógica)
# Calculamos los Lags sobre todo el histórico para no perder los primeros días de 2022
df_future['demanda_lag_1'] = df_future['demanda_real'].shift(1)
df_future['demanda_lag_24'] = df_future['demanda_real'].shift(24)
df_future['demanda_lag_168'] = df_future['demanda_real'].shift(168)
df_future['media_movil_24h'] = df_future['demanda_real'].shift(1).rolling(window=24).mean()

# Variables de tiempo
df_future['hora'] = df_future['fecha'].dt.hour
df_future['mes'] = df_future['fecha'].dt.month

# Variables de calendario (si el modelo las usa)
if 'es_finde' in features:
    df_future['dia_semana'] = df_future['fecha'].dt.dayofweek
    df_future['es_finde'] = df_future['dia_semana'].isin([5, 6]).astype(int)
if 'dia_semana' in features:
    df_future['dia_semana'] = df_future['fecha'].dt.dayofweek

# 4. FILTRADO: SOLO AÑO 2022
df_2022 = df_future[df_future['fecha'].dt.year == 2022].copy()
df_2022 = df_2022.dropna() # Borramos filas con NaNs por los lags

# 5. PREDICCIÓN
# Seleccionamos SOLO las columnas que el modelo conoce
try:
    X_2022 = df_2022[features]
    y_real_2022 = df_2022['demanda_real']
    
    preds_2022 = model.predict(X_2022)

    # 6. MÉTRICAS
    rmse_2022 = np.sqrt(mean_squared_error(y_real_2022, preds_2022))
    r2_2022 = r2_score(y_real_2022, preds_2022)

    print(f"\n RESULTADO FINAL (2022):")
    print(f"   R2 Score: {r2_2022:.4f} (Lo ideal es > 0.90)")
    print(f"   RMSEError: {rmse_2022:.2f} MW")

    # 7. GRÁFICO
    plt.figure(figsize=(18, 6))
    # Pintamos un subset para que sea ágil
    plt.plot(df_2022['fecha'][::4], y_real_2022[::4], label='Realidad 2022', color='grey', alpha=0.5)
    plt.plot(df_2022['fecha'][::4], preds_2022[::4], label='Predicción Modelo', color='#ff4b4b', linewidth=1)
    plt.title(f'Prueba de Fuego: Año 2022 Completo (R2: {r2_2022:.3f})', fontsize=15)
    plt.xlabel('Fecha')
    plt.ylabel('Demanda (MW)')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()

except KeyError as e:
    print(f"\nERROR DE COLUMNAS: {e}")
# Out:
# VALIDACIÓN FINAL: AÑO 2022
#  RESULTADO FINAL (2022):
#    R2 Score: 0.9907 (Lo ideal es > 0.90)
#    RMSEError: 411.90 MW
